# %% [markdown]
# GitHub API를 사용해봅니다

# %% [markdown]
# https://docs.github.com/ko/free-pro-team@latest/rest/repos/repos?apiVersion=2022-11-28#list-repositories-for-a-user

# %%
import requests


def fetch_user_repos(name):
    url = "https://api.github.com/users/{}/repos?sort=pushed&direction=desc&type=owner".format(name)

    response = requests.get(url)
    return response.json()

# %%
username = "aws"
# username = "Azure"

result = fetch_user_repos(username)
print(result)
# Out:
# [{'id': 152326454, 'node_id': 'MDEwOlJlcG9zaXRvcnkxNTIzMjY0NTQ=', 'name': 'aws-k8s-tester', 'full_name': 'aws/aws-k8s-tester', 'private': False, 'owner': {'login': 'aws', 'id': 2232217, 'node_id': 'MDEyOk9yZ2FuaXphdGlvbjIyMzIyMTc=', 'avatar_url': 'https://avatars.githubusercontent.com/u/2232217?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/aws', 'html_url': 'https://github.com/aws', 'followers_url': 'https://api.github.com/users/aws/followers', 'following_url': 'https://api.github.com/users/aws/following{/other_user}', 'gists_url': 'https://api.github.com/users/aws/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/aws/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/aws/subscriptions', 'organizations_url': 'https://api.github.com/users/aws/orgs', 'repos_url': 'https://api.github.com/users/aws/repos', 'events_url': 'https://api.github.com/users/aws/events{/privacy}', 'received_events_url': 'https://api.github.com/users/aws/received_events', 'type': 'Organization', 'site_admin': False}, 'html_url': 'https://github.com/aws/aws-k8s-tester', 'description': 'AWS Kubernetes tester, kubetest2 deployer implementation', 'fork': False, 'url': 'https://api.github.com/repos/aws/aws-k8s-tester', 'forks_url': 'https://api.github.com/repos/aws/aws-k8s-tester/forks', 'keys_url': 'https://api.github.com/repos/aws/aws-k8s-tester/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/aws/aws-k8s-tester/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/aws/aws-k8s-tester/teams', 'hooks_url': 'https://api.github.com/repos/aws/aws-k8s-tester/hooks', 'issue_events_url': 'https://api.github.com/repos/aws/aws-k8s-tester/issues/events{/number}', 'events_url': 'https://api.github.com/repos/aws/aws-k8s-tester/events', 'assignees_url': 'https://api.github.com/repos/aws/aws-k8s-tester/assignees{/user}', 'branches_url': 'https://api.github.com/repos/aws/aws-k8s-tester/branches{/branch}', 'tags_url': 'https://api.github.com/repos/aws/aws-k8s-tester/tags', 'blobs_url': 'https://api.github.com/repos/aws/aws-k8s-tester/git/blobs{/sha}', 'git_tags_url': 'https://api.github.com/repos/aws/aws-k8s-tester/git/tags{/sha}', 'git_refs_url': 'https://api.github.com/repos/aws/aws-k8s-tester/git/refs{/sha}', 'trees_url': 'https://api.github.com/repos/aws/aws-k8s-tester/git/trees{/sha}', 'statuses_url': 'https://api.github.com/repos/aws/aws-k8s-tester/statuses/{sha}', 'languages_url': 'https://api.github.com/repos/aws/aws-k8s-tester/languages', 'stargazers_url': 'https://api.github.com/repos/aws/aws-k8s-tester/stargazers', 'contributors_url': 'https://api.github.com/repos/aws/aws-k8s-tester/contributors', 'subscribers_url': 'https://api.github.com/repos/aws/aws-k8s-tester/subscribers', 'subscription_url': 'https://api.github.com/repos/aws/aws-k8s-tester/subscription', 'commits_url': 'https://api.github.com/repos/aws/aws-k8s-tester/commits{/sha}', 'git_commits_url': 'https://api.github.com/repos/aws/aws-k8s-tester/git/commits{/sha}', 'comments_url': 'https://api.github.com/repos/aws/aws-k8s-tester/comments{/number}', 'issue_comment_url': 'https://api.github.com/repos/aws/aws-k8s-tester/issues/comments{/number}', 'contents_url': 'https://api.github.com/repos/aws/aws-k8s-tester/contents/{+path}', 'compare_url': 'https://api.github.com/repos/aws/aws-k8s-tester/compare/{base}...{head}', 'merges_url': 'https://api.github.com/repos/aws/aws-k8s-tester/merges', 'archive_url': 'https://api.github.com/repos/aws/aws-k8s-tester/{archive_format}{/ref}', 'downloads_url': 'https://api.github.com/repos/aws/aws-k8s-tester/downloads', 'issues_url': 'https://api.github.com/repos/aws/aws-k8s-tester/issues{/number}', 'pulls_url': 'https://api.github.com/repos/aws/aws-k8s-tester/pulls{/number}', 'milestones_url': 'https://api.github.com/repos/aws/aws-k8s-tester/milestones{/number}', 'notifications_url': 'https://api.github.com/repos/aws/aws-k8s-tester/notifications{?since,all,participating}', 'labels_url': ...

# %%
print(result[1])
repo = result[1]
# Out:
# {'id': 36883937, 'node_id': 'MDEwOlJlcG9zaXRvcnkzNjg4MzkzNw==', 'name': 'aws-parallelcluster-cookbook', 'full_name': 'aws/aws-parallelcluster-cookbook', 'private': False, 'owner': {'login': 'aws', 'id': 2232217, 'node_id': 'MDEyOk9yZ2FuaXphdGlvbjIyMzIyMTc=', 'avatar_url': 'https://avatars.githubusercontent.com/u/2232217?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/aws', 'html_url': 'https://github.com/aws', 'followers_url': 'https://api.github.com/users/aws/followers', 'following_url': 'https://api.github.com/users/aws/following{/other_user}', 'gists_url': 'https://api.github.com/users/aws/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/aws/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/aws/subscriptions', 'organizations_url': 'https://api.github.com/users/aws/orgs', 'repos_url': 'https://api.github.com/users/aws/repos', 'events_url': 'https://api.github.com/users/aws/events{/privacy}', 'received_events_url': 'https://api.github.com/users/aws/received_events', 'type': 'Organization', 'site_admin': False}, 'html_url': 'https://github.com/aws/aws-parallelcluster-cookbook', 'description': 'The Chef cookbook used to build and bootstrap AWS ParallelCluster', 'fork': False, 'url': 'https://api.github.com/repos/aws/aws-parallelcluster-cookbook', 'forks_url': 'https://api.github.com/repos/aws/aws-parallelcluster-cookbook/forks', 'keys_url': 'https://api.github.com/repos/aws/aws-parallelcluster-cookbook/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/aws/aws-parallelcluster-cookbook/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/aws/aws-parallelcluster-cookbook/teams', 'hooks_url': 'https://api.github.com/repos/aws/aws-parallelcluster-cookbook/hooks', 'issue_events_url': 'https://api.github.com/repos/aws/aws-parallelcluster-cookbook/issues/events{/number}', 'events_url': 'https://api.github.com/repos/aws/aws-parallelcluster-cookbook/events', 'assignees_url': 'https://api.github.com/repos/aws/aws-parallelcluster-cookbook/assignees{/user}', 'branches_url': 'https://api.github.com/repos/aws/aws-parallelcluster-cookbook/branches{/branch}', 'tags_url': 'https://api.github.com/repos/aws/aws-parallelcluster-cookbook/tags', 'blobs_url': 'https://api.github.com/repos/aws/aws-parallelcluster-cookbook/git/blobs{/sha}', 'git_tags_url': 'https://api.github.com/repos/aws/aws-parallelcluster-cookbook/git/tags{/sha}', 'git_refs_url': 'https://api.github.com/repos/aws/aws-parallelcluster-cookbook/git/refs{/sha}', 'trees_url': 'https://api.github.com/repos/aws/aws-parallelcluster-cookbook/git/trees{/sha}', 'statuses_url': 'https://api.github.com/repos/aws/aws-parallelcluster-cookbook/statuses/{sha}', 'languages_url': 'https://api.github.com/repos/aws/aws-parallelcluster-cookbook/languages', 'stargazers_url': 'https://api.github.com/repos/aws/aws-parallelcluster-cookbook/stargazers', 'contributors_url': 'https://api.github.com/repos/aws/aws-parallelcluster-cookbook/contributors', 'subscribers_url': 'https://api.github.com/repos/aws/aws-parallelcluster-cookbook/subscribers', 'subscription_url': 'https://api.github.com/repos/aws/aws-parallelcluster-cookbook/subscription', 'commits_url': 'https://api.github.com/repos/aws/aws-parallelcluster-cookbook/commits{/sha}', 'git_commits_url': 'https://api.github.com/repos/aws/aws-parallelcluster-cookbook/git/commits{/sha}', 'comments_url': 'https://api.github.com/repos/aws/aws-parallelcluster-cookbook/comments{/number}', 'issue_comment_url': 'https://api.github.com/repos/aws/aws-parallelcluster-cookbook/issues/comments{/number}', 'contents_url': 'https://api.github.com/repos/aws/aws-parallelcluster-cookbook/contents/{+path}', 'compare_url': 'https://api.github.com/repos/aws/aws-parallelcluster-cookbook/compare/{base}...{head}', 'merges_url': 'https://api.github.com/repos/aws/aws-parallelcluster-cookbook/merges', 'archive_url': 'https://api.github.com/repos/aws/aws-parallelcluster-cookbook/{archive_format}{/ref} ...

# %%
print(repo['language'])
# Out:
# Ruby

# %% [markdown]
# 이제 GitHub Apps를 이용해봅니다.
# https://github.com/settings/apps
